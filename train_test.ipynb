# %% [markdown]
# # To train the Object detection Model:

# %%
from ultralytics import YOLO

# # Load a model
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# # Train the model with 2 GPUs
results = model.train(data='data.yaml', epochs=2, imgsz=640)
# Out:
# yolo\engine\trainer: task=detect, mode=train, model=yolov8n.yaml, data=data.yaml, epochs=2, patience=50, batch=16, imgsz=640, save=True, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=False, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=True, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, retina_masks=False, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.
# ...

# %% [markdown]
# # Test Object Detection Model:

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('ultralytics/runs/detect/train_model/weights/best.pt')

# Run inference on 'bus.jpg' with arguments
model.predict("C:\\Users\\aravi\\ANPR\\Automatic-Number-Plate-Recognition--ANPR-\\runs\\detect\\train7\\WhatsApp Video 2024-03-03 at 8.54.43 PM.mp4", save=True, imgsz=320, conf=0.2)
# Out:
# Ultralytics YOLOv8.0.3  Python-3.11.0 torch-2.2.1+cpu CPU
# Fusing layers...
# Model summary: 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# video 1/1 (1/550) C:\Users\aravi\ANPR\Automatic-Number-Plate-Recognition--ANPR-\runs\detect\train7\WhatsApp Video 2024-03-03 at 8.54.43 PM.mp4: 320x192 122.4ms
# video 1/1 (2/550) C:\Users\aravi\ANPR\Automatic-Number-Plate-Recognition--ANPR-\runs\detect\train7\WhatsApp Video 2024-03-03 at 8.54.43 PM.mp4: 320x192 66.6ms
# video 1/1 (3/550) C:\Users\aravi\ANPR\Automatic-Number-Plate-Recognition--ANPR-\runs\detect\train7\WhatsApp Video 2024-03-03 at 8.54.43 PM.mp4: 320x192 68.7ms
# video 1/1 (4/550) C:\Users\aravi\ANPR\Automatic-Number-Plate-Recognition--ANPR-\runs\detect\train7\WhatsApp Video 2024-03-03 at 8.54.43 PM.mp4: 320x192 60.7ms
# video 1/1 (5/550) C:\Users\aravi\ANPR\Automatic-Number-Plate-Recognition--ANPR-\runs\detect\train7\WhatsApp Video 2024-03-03 at 8.54.43 PM.mp4: 320x192 60.6ms
# ...

# %% [markdown]
# # Recognize License plate after Detecting  using easy-ocr

# %%
# %pip install easyocr
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 23.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python predict_modified.py model='ultralytics/runs/detect/train_model/weights/best.pt' source="C:\\Users\\aravi\\ANPR\\Automatic-Number-Plate-Recognition--ANPR-\\runs\\detect\\train7\\WhatsApp Video 2024-03-03 at 8.54.30 PM.mp4"
# Out:
# FthOscbOZzH
# 'TnO5cb072
#
# TNOsCbOZ2]
# TNOSCBOZZ:
# TNOSCDDZ
# TnOscbO72]
# TNO5CbOZL]
# TNO5CbO72]
# TnOsCb0z2]
# TNO5cbOZ2]
# tnO5cb072y
# TnO5Cb072y
# TnO5CBO724
# Tno5CB0724
# TnO5cb0724
# TNO5CB0724
# TNO5CBO724
# TNO5cB0724
# TNO5CB0724
# TNO5CBO724
# TNO5CB0724
# TNO5CBO724
# TNO5CBO724
# TNO5CBO724
# TNO5CB0724
# TNOSCBO724
# TNO5cB0724
# TNO5CBO724
# TNOSCBO724
# TNO5CBO724
# TNO5CBO724
# TNO5CBO724
# TNOSCB0724
#
# TNOSCBO724
# TNOSCBO724
#
# TNO5CBO724
# TNO5CBO724
# TNOSCBO724
# TNO5CB0724
# TNOSCB0724
#
# TNOSCBO724
# TNO5CB0724
# Enoscbo72
# TnOScBd
#
#
#
# (TN05CFo724
# TNOSCB0724
# kNoscbo
#
#
#
# TNOSCBO
# TNOSCBIz24
#
# TNOSCBIz24
# TNOSCBC
# TNOSCBIF
# TNOSCBC
# TNOSCBIE
# TROSCBI
# TNO5CBI724
# TNOSCBO
# TNOSCBIh2y
# TNOSCBI
# TNOSCBI224
#
#
# TNO5Coz
#
# Tn05C20724
# TNO5C2oz
# TNO5CBO724
# TNOSCBO7
# TNOscBO724
# TNOSCBO7
# TNoscB0724
# TnOscBo7
# TNOsCBO724
# TNOSCBO
# TNOSCBO
# TNOSCBO
# TNOSCBO724
# TNOSCBQ
# TNO5CBO724
# TNOSCBQ
#
# TN05Ch0724
# TNO5C0z2
# ...
